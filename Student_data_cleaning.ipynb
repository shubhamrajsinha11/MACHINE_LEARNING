# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_data.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head(10
            )
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.describe(include="O")
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     395     395     395    395    395     395      395
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     307     281     354    141    217     145      273
#
#        schoolsup famsup paid activities nursery higher internet romantic
# count        395    395  395        395     395    395      395      395
# unique         2      2    2          2       2      2        2        2
# top           no    yes   no        yes     yes    yes      yes       no
# freq         344    242  214        201     314    375      329      263

# %% [markdown]
# Handel Duplicates Value

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Length: 395, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# # Aggregating Absences Data in a DataFrame

# %%
df["absences"].agg(["max" , "min" , "mean"])
# Out:
# max     75.000000
# min      0.000000
# mean     5.708861
# Name: absences, dtype: float64

# %%
df['Avg Score']= ((df['G1']+df['G2']+df['G3'])/3)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df["Performance Category"] = pd.qcut(df["Avg Score"] , q=3 , labels=["Low" , "Medium" , "High"])
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
pivot=df.pivot_table(index='Mjob',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# Mjob
# at_home    9.762712
# health    12.235294
# other     10.059102
# services  11.207120
# teacher   11.270115

# %%
pivot=df.pivot_table(index='Fjob',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# Fjob
# at_home   10.816667
# health    11.481481
# other     10.390169
# services  10.669670
# teacher   12.287356

# %%
pivot=df.pivot_table(index='Pstatus',values='Avg Score',aggfunc='mean')
pivot
# Out:
#          Avg Score
# Pstatus
# A        11.146341
# T        10.625235

# %%
pivot=df.pivot_table(index='internet',values='Avg Score',aggfunc='mean')
pivot
# Out:
#           Avg Score
# internet
# no         9.833333
# yes       10.849037

# %%
pivot=df.pivot_table(index='higher',values='Avg Score',aggfunc='mean')
pivot
# Out:
#         Avg Score
# higher
# no       7.650000
# yes     10.840889

# %%
pivot=df.pivot_table(index='school',values='failures',aggfunc='mean')
pivot
# Out:
#         failures
# school
# GP      0.318052
# MS      0.456522

# %%
pivot=df.pivot_table(index='school',values='Avg Score',aggfunc='mean')
pivot
# Out:
#         Avg Score
# school
# GP      10.737345
# MS      10.239130

# %%
df[df["famsize"].isin(["GT3"])]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
# ...

# %% [markdown]
# # univariate analysis

# %%
mj =df['Mjob'].value_counts()
mj
# Out:
# Mjob
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: count, dtype: int64

# %%
plt.bar(mj.index ,mj.values ,color ='purple' )
plt.title('Mjob Distribution')
plt.xlabel('Mjob')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
colors = plt.cm.tab10.colors[:len(mj)]  

plt.pie(x=mj, labels=mj.index, autopct="%0.0f%%", shadow=True, colors=colors)
plt.title('Mjob')
plt.legend(loc=1)  
plt.show()

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
Fjob=df['Fjob'].value_counts()
Fjob
# Out:
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: count, dtype: int64

# %%
plt.bar(mj.index ,mj.values ,color ='purple' )
plt.title('Fjob Distribution')
plt.xlabel('Fjob')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
plt.pie(x=Fjob ,labels=Fjob.index ,autopct='%0.0f%%' ,shadow=True,explode=[0,0,0,0.3,0.2])
plt.title('Fjob distribution')
plt.legend(loc=1)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
school=df['school'].value_counts()
school
# Out:
# school
# GP    349
# MS     46
# Name: count, dtype: int64

# %%
plt.bar(school.index ,school.values ,color ='purple' )
plt.title('School Distribution')
plt.xlabel('School')
plt.ylabel('count')
plt.pie(x=school ,labels=school.index ,autopct='%0.0f%%' ,shadow=True,explode=[0,0.3])
plt.title('School distribution')
plt.legend(loc=1)
plt.show()

# %%
df["absences"].agg(["min", "max", "mean"])
# Out:
# min      0.000000
# max     75.000000
# mean     5.708861
# Name: absences, dtype: float64

# %%
df[df["absences"] == 75.000000]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  ...  \
# 276     GP   F   18       R     GT3       A     3     2  other  services  ...
#
#     goout Dalc  Walc  health  absences  G1 G2 G3 Avg Score  \
# 276     1    1     1       5        75  10  9  9  9.333333
#
#     Performance Category
# 276               Medium
#
# [1 rows x 35 columns]

# %%
df[df["absences"]==0.000000]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 14      GP   M   15       U     GT3       A     2     2     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 383     MS   M   19       R     GT3       T     1     1     other  services
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
absences=df['absences'].value_counts()
absences
# Out:
# absences
# 0     115
# 2      65
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     12
# 3       8
# 7       7
# 16      7
# 18      5
# 5       5
# 20      4
# 13      3
# 15      3
# 1       3
# 22      3
# 9       3
# 11      3
# 28      1
# 24      1
# 54      1
# 25      1
# 56      1
# 26      1
# 75      1
# 21      1
# 19      1
# 30      1
# 38      1
# 40      1
# 23      1
# 17      1
# Name: count, dtype: int64

# %%
plt.bar(absences.index ,absences.values ,color ='purple' )
plt.title('absences Distribution')
plt.xlabel('absences')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
absences = absences.sort_values(ascending=False)


threshold = absences.sum() * 0.03  
absences_filtered = absences[absences >= threshold]
other_sum = absences[absences < threshold].sum()
if other_sum > 0:
    absences_filtered["Other"] = other_sum 


explode = [0.1 if i < 3 else 0 for i in range(len(absences_filtered))]


colors = plt.cm.get_cmap("tab20").colors[:len(absences_filtered)]


plt.figure(figsize=(12, 12))


wedges, texts, autotexts = plt.pie(
    absences_filtered, 
    labels=absences_filtered.index, 
    autopct='%0.1f%%', 
    shadow=True, 
    colors=colors, 
    startangle=140, 
    pctdistance=0.6,  
    labeldistance=1.1, 
    explode=explode  
)


for text in texts:
    text.set_fontsize(14)  
for autotext in autotexts:
    autotext.set_fontsize(14)  
    plt.title('Absences Distribution', fontsize=18)


plt.legend(wedges, absences_filtered.index, title="Categories", loc="center left", bbox_to_anchor=(1, 0.5), fontsize=12)

plt.show()
# Out:
# C:\Users\Spyke\AppData\Local\Temp\ipykernel_10896\3492976177.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab20").colors[:len(absences_filtered)]

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(8, 15))
    values = df[col].value_counts() 
    plt.pie(values, labels=values.index, autopct='%.1f%%', shadow=False)
    plt.title(f'{col} students')
    plt.show()

# %%
sns.scatterplot(x='G1', y='G3', data=df, hue='Performance Category', palette='Set1')
sns.scatterplot(x='G2', y='G3', data=df, hue='Performance Category', palette='Set1')
sns.scatterplot(x='G1', y='G2', data=df, hue='Performance Category', palette='Set1')
sns.pairplot(df, hue='Performance Category', palette='Set1', diag_kind='kde')

# %% [markdown]
# # Outlier Check: Absences

# %%
# absences has a max of 75 vs a median of 4 - checking how many extreme outliers exist
print(df["absences"].describe())
outliers = df[df["absences"] > 40]
print(f"\nRows with absences > 40: {len(outliers)}")
outliers[["school","age","absences","G1","G2","G3"]]
# Out:
# count    395.000000
# mean       5.708861
# std        8.003096
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max       75.000000
# Name: absences, dtype: float64
#
# Rows with absences > 40: 3
#     school  age  absences  G1  G2  G3
# 74      GP   16        54  11  12  11
# 183     GP   17        56   9   9   8
# 276     GP   18        75  10   9   9

# %% [markdown]
# # Covariance Matrix

# %%
numeric_df = df.select_dtypes(include="number")
cov_matrix = numeric_df.cov()
cov_matrix
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.628285 -0.228619 -0.226949    0.062873  -0.004434  0.231221
# Medu       -0.228619  1.198445  0.742717   -0.131061   0.059667 -0.192681
# Fedu       -0.226949  0.742717  1.184180   -0.120073  -0.008379 -0.202641
# traveltime  0.062873 -0.131061 -0.120073    0.486513  -0.059070  0.047844
# studytime  -0.004434  0.059667 -0.008379   -0.059070   0.704324 -0.108321
# failures    0.231221 -0.192681 -0.202641    0.047844  -0.108321  0.553017
# famrel      0.061717 -0.003842 -0.001337   -0.010512   0.029898 -0.029564
# freetime    0.020947  0.033779 -0.013963   -0.011861  -0.120041  0.068329
# goout       0.180364  0.078115  0.052220    0.022162  -0.059706  0.103123
# Dalc        0.149039  0.019341  0.002313    0.085941  -0.146533  0.090118
# Walc        0.192733 -0.066440 -0.017702    0.120478  -0.274304  0.135964
# health     -0.110326 -0.071349  0.022303    0.007274  -0.088228  0.068059
# ...

# %% [markdown]
# # Correlation Matrix

# %%
corr_matrix = numeric_df.corr()
corr_matrix
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix - Student Data")
plt.tight_layout()
plt.show()

# %%
# Which features correlate most strongly with the final grade G3?
corr_matrix["G3"].sort_values(ascending=False)
# Out:
# G3            1.000000
# Avg Score     0.959873
# G2            0.904868
# G1            0.801468
# Medu          0.217147
# Fedu          0.152457
# studytime     0.097820
# famrel        0.051363
# absences      0.034247
# freetime      0.011307
# Walc         -0.051939
# Dalc         -0.054660
# health       -0.061335
# traveltime   -0.117142
# goout        -0.132791
# age          -0.161579
# failures     -0.360415
# Name: G3, dtype: float64

# %% [markdown]
# # Scatterplots: Checking Linearity

# %%
from scipy import stats

pairs = [("G1","G3"), ("G2","G3"), ("studytime","G3"), ("absences","G3"), ("failures","G3"), ("Medu","G3")]

fig, axes = plt.subplots(2, 3, figsize=(18,10))
for ax, (x, y) in zip(axes.flat, pairs):
    sns.regplot(x=x, y=y, data=df, ax=ax, scatter_kws={"alpha":0.4,"s":20}, line_kws={"color":"red"})
    r, p = stats.pearsonr(df[x], df[y])
    rho, ps = stats.spearmanr(df[x], df[y])
    ax.set_title(f"{x} vs {y}\nPearson r={r:.2f}, Spearman rho={rho:.2f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion: Linear or Non-linear?
#
# - **G1 vs G3** and **G2 vs G3** show a strong, clearly linear relationship (Pearson r close to Spearman rho, both high) — earlier grades are a straightforward linear predictor of the final grade.
# - **studytime vs G3**, **Medu vs G3** show weak positive relationships — not strongly linear, a lot of scatter/noise, low r.
# - **absences vs G3** and **failures vs G3** show weak-to-moderate, non-linear or noisy patterns. `failures` in particular has a negative but non-linear step-like relationship (since it only takes values 0-3), so treat it as a mostly ordinal/categorical effect rather than a continuous linear one.
# - When Pearson r and Spearman rho diverge noticeably for a pair, that is a sign the relationship is monotonic but not linear (a straight line is not the best fit, but a consistent increasing/decreasing trend still exists).
