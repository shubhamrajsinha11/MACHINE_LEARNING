# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv('standard_scaler_dataset.csv')
df
# Out:
#     Age  Salary  Experience
# 0    56   32695           3
# 1    46   78190           7
# 2    32   35258           6
# 3    60  117538           8
# 4    25   69504          27
# ..  ...     ...         ...
# 95   24   96842          23
# 96   26   91373          10
# 97   41   36776           3
# 98   18  122787           7
# 99   61   85016          28
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    Age  Salary  Experience
# 0   56   32695           3
# 1   46   78190           7
# 2   32   35258           6
# 3   60  117538           8
# 4   25   69504          27

# %%
X = df.drop(columns='Salary')
y = df['Salary']

# %%
sns.boxplot(X)
# Out:
# <Axes: >

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

# %%
xtrain[['Experience_Years','Age','Hours_Per_Week']] =standard_scaler.fit_transform(xtrain[['Experience_Years','Age','Hours_Per_Week']])

# %%
xtrain
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 249          0.410116 -1.487863                1        0.525855
# 433          0.731716 -2.318167                3       -0.909748
# 19          -1.442912  0.774504                4        0.217080
# 322         -0.840550  2.395274                1        1.163455
# 332          0.073202 -1.066421                2        0.078733
# ..                ...       ...              ...             ...
# 106          1.921126 -0.825298                4        0.475729
# 270          1.466802  0.728377                3       -1.260629
# 348         -0.738455 -0.682720                1       -1.062131
# 435          0.073202 -0.540143                1        0.970972
# 102         -0.355598  0.898211                4       -0.731300
#
# [400 rows x 4 columns]

# %%
xtrain['Experience_Years'].mean()
# Out:
# np.float64(1.3655743202889425e-16)

# %%
xtrain['Experience_Years'].std()
# Out:
# np.float64(1.0012523486435176)

# %%
xtrain['Age'].mean()
# Out:
# np.float64(-6.572520305780927e-16)

# %%
xtrain['Age'].std()
# Out:
# np.float64(1.0012523486435176)

# %%
xtrain['Education_Level'] = minmax_scaler.fit_transform(xtrain[['Education_Level']])

# %%
xtrain
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 249          0.410116 -1.487863         0.000000        0.525855
# 433          0.731716 -2.318167         0.666667       -0.909748
# 19          -1.442912  0.774504         1.000000        0.217080
# 322         -0.840550  2.395274         0.000000        1.163455
# 332          0.073202 -1.066421         0.333333        0.078733
# ..                ...       ...              ...             ...
# 106          1.921126 -0.825298         1.000000        0.475729
# 270          1.466802  0.728377         0.666667       -1.260629
# 348         -0.738455 -0.682720         0.000000       -1.062131
# 435          0.073202 -0.540143         0.000000        0.970972
# 102         -0.355598  0.898211         1.000000       -0.731300
#
# [400 rows x 4 columns]

# %%
xtest[['Experience_Years','Age','Hours_Per_Week']] = standard_scaler.transform(xtest[['Experience_Years','Age','Hours_Per_Week']])

# %%
xtest
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 361          1.563792 -1.603183                2       -0.334304
# 73           1.594421 -0.244504                1        0.549915
# 374          2.196783 -0.049509                1        0.233120
# 155         -0.733350  0.049037                1        0.700293
# 104         -0.166721  0.420158                4       -0.236057
# ..                ...       ...              ...             ...
# 347         -1.437807  2.560915                1        0.407558
# 86           0.930802 -0.496112                3       -0.849597
# 75           0.833812 -2.332844                4       -0.378415
# 438         -1.744093  0.241936                3       -1.020025
# 15          -0.575102  0.778698                1        0.834630
#
# [100 rows x 4 columns]

# %%
xtest['Education_Level'] = standard_scaler.transform(xtest[['Education_Level']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 xtest['Education_Level'] = standard_scaler.transform(xtest[['Education_Level']])
#
# NameError: name 'standard_scaler' is not defined
