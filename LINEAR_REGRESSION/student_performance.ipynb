# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('Student_Performance1.csv')
df.corr(numeric_only=True)
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
y_train = y_train.map({'Yes': 1, 'No': 0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y_train = y_train.map({'Yes': 1, 'No': 0})
#
# NameError: name 'y_train' is not defined

# %%
x=df.drop(columns=['Performance Index'])
y=df['Performance Index']

# %%
df.shape
# Out:
# (10000, 6)

# %% [markdown]
# # UNPACKING

# %%
# train-test-split method returns list of 4 values, so we can unpack them into 4 variables.
# first 2 values belongs to x and last 2 values belongs to y.
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
x_train
# each time the sample data is changing, that will affect our accuracy of the model.
# to fix this we can use random_state parameter, which will fix the sample data and will not change it.
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9254              5               49                         No            7
# 1561              2               48                        Yes            7
# 1670              2               81                         No            7
# 6087              2               46                         No            6
# 6669              8               47                         No            9
# ...             ...              ...                        ...          ...
# 5734              8               50                        Yes            6
# 5191              4               68                         No            9
# 5390              9               48                         No            7
# 860               1               47                         No            9
# 7270              2               46                         No            6
#
#       Sample Question Papers Practiced
# ...

# %%
y_train
# Out:
# 9254    36.0
# 1561    25.0
# 1670    59.0
# 6087    22.0
# 6669    40.0
#         ...
# 5734    48.0
# 5191    51.0
# 5390    44.0
# 860     20.0
# 7270    24.0
# Name: Performance Index, Length: 8000, dtype: float64

# %% [markdown]
# # MODEL CREATION

# %%
model=LinearRegression()

# %% [markdown]
# # MODEL TRAINING

# %%
print(x_train.dtypes)
# Out:
# Hours Studied                        int64
# Previous Scores                      int64
# Extracurricular Activities          object
# Sleep Hours                          int64
# Sample Question Papers Practiced     int64
# dtype: object

# %%
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.fit(x_train, y_train)
#
# NameError: name 'model' is not defined
